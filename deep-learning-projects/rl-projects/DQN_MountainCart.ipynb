# %%
import gym
import numpy as np
import torch
import matplotlib
import matplotlib.pyplot as plt
import time

from collections import deque

# %%
GAMMA = 0.99
LEARNING_RATE = 0.01
TARGET_UPDATE = 10

n_episodes = 100000
hidden_dim = 16
min_eps = 0.01
max_eps_episode = 50

# %% [markdown]
# ### NN - Q Network

# %%
import torch.nn as nn

class QNN(nn.Module):
    def __init__(self, ip_dim, op_dim, hid_dim) -> None:
        
        super(QNN, self).__init__()
        self.layer1 = torch.nn.Sequential(
            torch.nn.Linear(ip_dim, hid_dim),
            torch.nn.PReLU()
        )

        self.layer2 = torch.nn.Sequential(
            torch.nn.Linear(hid_dim, hid_dim),
            torch.nn.PReLU()
        )

        self.layer3 = torch.nn.Sequential(
            torch.nn.Linear(hid_dim, hid_dim),
            torch.nn.PReLU()
        )
        
        self.final = torch.nn.Linear(hid_dim, op_dim)
        
    def forward(self, t: torch.Tensor) -> torch.Tensor:
        t = self.layer1(t)
        t = self.layer2(t)
        t = self.layer3(t)
        t = self.final(t)

        return t

# %% [markdown]
# ## relay memory
#
# reference: https://docs.python.org/3/library/collections.html#collections.namedtuple

# %%
import random
from collections import namedtuple

transition = namedtuple('transition',('state', 'action', 'reward','nxt_state','stop'))

class ReplayMemory_CyclicBuffer(object):
    
    def __init__(self, capacity):
        self.memory = deque([], maxlen=capacity) 
            
    def __len__(self):
        return len(self.memory)
        
    def push_to_memory(self, *args):
        self.memory.append(transition(*args))
        
    def random_sampling(self, batch_size):
        return random.sample(self.memory, batch_size)
    
    
# test = transition(((1,2),(2,3),(4,5)),('stay','left','right'),(1,1,1),((4,5),(6,7),(8,9)))
# print(test)

# %% [markdown]
# ## Agent

# %%
import torch.optim as optim

from torch.autograd import Variable

BATCH_SIZE = 64
FloatTensor = torch.FloatTensor #32-bit float multi dimension matrix

class Agent_MountainCart(object):
    
    def __init__(self, n_states, n_actions, hidden_dim, learning_rate):
        self.device = torch.device("cpu")
        self.local_q = QNN(n_states, n_actions, hidden_dim).to(self.device)
        self.target_q = QNN(n_states, n_actions, hidden_dim).to(self.device)
        
        self.mse_loss = torch.nn.MSELoss()
        self.optim = optim.Adam(self.local_q.parameters(), lr=learning_rate)
        
        self.n_states = n_states
        self.n_actions = n_actions
        
        self.replay_memory = ReplayMemory_CyclicBuffer(10000)
        
        
    def get_action(self, state, eps_greedy, eps_flag = True):
        global steps_done
        
        random_sample = random.random()
        
        if random_sample > eps_greedy:
            with torch.no_grad():
                return self.local_q((state).type(FloatTensor)).data.max(1)[1].view(1,1)
        else:
            return torch.tensor([[random.randrange(self.n_actions)]])
        
    def learn(self, experience, GAMMA):
        
        if len(self.replay_memory.memory) < BATCH_SIZE:
            return;
        
        transitions_sample = self.replay_memory.random_sampling(BATCH_SIZE)
        batch = transition(*zip(*transitions_sample))
        
        states = torch.cat(batch.state)
        actions = torch.cat(batch.action)
        rewards = torch.cat(batch.reward)
        nxt_states = torch.cat(batch.nxt_state)
        stops = torch.cat(batch.stop)
        
        expected_Q = torch.gather(self.local_q(states),1,actions)
        nxt_targets_Q = self.target_q(nxt_states).detach().max(1)[0]
        targets_Q = rewards + (GAMMA * nxt_targets_Q * (1-stops)) #1-dones
        self.local_q.train(mode = True)
        self.optim.zero_grad()
        loss = self.mse_loss(expected_Q, targets_Q.unsqueeze(1))
        loss.backward()
        self.optim.step()

# %%
# set up matplotlib
is_ipython = 'inline' in matplotlib.get_backend()
if is_ipython:
    from IPython import display

plt.ion()

# %%
env = gym.make('MountainCar-v0')

dim_space = env.observation_space.shape[0]
dim_action = env.action_space.n

threshold = env.spec.reward_threshold

print('ip_dim:', dim_space, 'op_dim:', dim_action,'hidden_dim:',hidden_dim,'threshold:', threshold)

agent = Agent_MountainCart(dim_space, dim_action, hidden_dim, learning_rate=LEARNING_RATE)

def epsilon_annealing(i_episode, max_episode, min_eps: float):
    
    slope = (min_eps - 1.0)/max_episode
    max_eps = max(slope * i_episode + 1.0, min_eps)
    return max_eps

def save_q(directory, filename):
    torch.save(agent.local_q.state_dict(), '%s/%s_local.pth' % (directory, filename))
    torch.save(agent.target_q.state_dict(), '%s/%s_target.pth' % (directory, filename))
# Out:
# ip_dim: 2 op_dim: 3 hidden_dim: 16 threshold: -110.0

# %%
def play_episode(env, agent, eps):
    
    state = env.reset()
    stop = False
    total_reward = 0
    
    while not stop:
        action = agent.get_action(FloatTensor([state]), eps)
#         print("action in play_eps:", action)
#         print("int action:", int(action.item()))
#         print("env step:",env.step(int(action.item())))
        nxt_state, reward, stop, _ = env.step(action.item())
        total_reward = total_reward + reward
        
        if stop:
            reward = -1
            
        agent.replay_memory.push_to_memory(
            FloatTensor([state]),
             action,
             FloatTensor([reward]),
             FloatTensor([nxt_state]),
             FloatTensor([stop])
        )
        
        if(len(agent.replay_memory) > BATCH_SIZE):
            batch = agent.replay_memory.random_sampling(BATCH_SIZE)
            agent.learn(batch, GAMMA)
            
        state = nxt_state
        
    return total_reward

# %%
def train():
    scores = deque(maxlen=100)
    temp_scores = []
    avg_scores = []
    
    start_time = time.time()
    
    for i_episode in range(n_episodes):
        eps = epsilon_annealing(i_episode, max_eps_episode, min_eps)
        score = play_episode(env, agent, eps)
        
        scores.append(score)
        temp_scores.append(score)
        
        avg_score = np.mean(scores)
        avg_scores.append(avg_score)
        
        dt = (int)(time.time() - start_time)
        
        if i_episode % 10 == 0 and i_episode > 0:
            print('Episode: {:5} Score: {:5}  Avg.Score: {:.2f}, eps-greedy: {:5.3f} Time: {:02}:{:02}:{:02}'.\
                    format(i_episode, score, avg_score, eps, dt//3600, dt%3600//60, dt%60))
            
        if len(scores) == 100 and  avg_score >= threshold: 
                print('\n MountainCart solved in {:d} episodes!\tAverage Score: {:.2f}'. \
                    format(i_episode, np.mean(scores)))
                break
                
        if i_episode % TARGET_UPDATE == 0:
            agent.target_q.load_state_dict(agent.local_q.state_dict()) 
                
    return temp_scores, avg_scores

scores, avg_scores = train()
# Out:
# <ipython-input-8-9b96adf53acf>:8: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   action = agent.get_action(FloatTensor([state]), eps)
# Episode:    10 Score: -200.0  Avg.Score: -200.00, eps-greedy: 0.802 Time: 00:00:02
# Episode:    20 Score: -200.0  Avg.Score: -200.00, eps-greedy: 0.604 Time: 00:00:04
# Episode:    30 Score: -200.0  Avg.Score: -200.00, eps-greedy: 0.406 Time: 00:00:06
# Episode:    40 Score: -200.0  Avg.Score: -200.00, eps-greedy: 0.208 Time: 00:00:08
# Episode:    50 Score: -200.0  Avg.Score: -200.00, eps-greedy: 0.010 Time: 00:00:11
# Episode:    60 Score: -200.0  Avg.Score: -200.00, eps-greedy: 0.010 Time: 00:00:13
# Episode:    70 Score: -200.0  Avg.Score: -200.00, eps-greedy: 0.010 Time: 00:00:15
# Episode:    80 Score: -200.0  Avg.Score: -200.00, eps-greedy: 0.010 Time: 00:00:18
# Episode:    90 Score: -200.0  Avg.Score: -200.00, eps-greedy: 0.010 Time: 00:00:20
# Episode:   100 Score: -200.0  Avg.Score: -200.00, eps-greedy: 0.010 Time: 00:00:22
# Episode:   110 Score: -200.0  Avg.Score: -200.00, eps-greedy: 0.010 Time: 00:00:24
# Episode:   120 Score: -200.0  Avg.Score: -200.00, eps-greedy: 0.010 Time: 00:00:27
# Episode:   130 Score: -200.0  Avg.Score: -200.00, eps-greedy: 0.010 Time: 00:00:29
# Episode:   140 Score: -200.0  Avg.Score: -200.00, eps-greedy: 0.010 Time: 00:00:31
# Episode:   150 Score: -200.0  Avg.Score: -200.00, eps-greedy: 0.010 Time: 00:00:34
# Episode:   160 Score: -200.0  Avg.Score: -200.00, eps-greedy: 0.010 Time: 00:00:36
# Episode:   170 Score: -200.0  Avg.Score: -200.00, eps-greedy: 0.010 Time: 00:00:38
# Episode:   180 Score: -200.0  Avg.Score: -200.00, eps-greedy: 0.010 Time: 00:00:41
# Episode:   190 Score: -200.0  Avg.Score: -200.00, eps-greedy: 0.010 Time: 00:00:43
# Episode:   200 Score: -200.0  Avg.Score: -200.00, eps-greedy: 0.010 Time: 00:00:45
# Episode:   210 Score: -200.0  Avg.Score: -200.00, eps-greedy: 0.010 Time: 00:00:47
# Episode:   220 Score: -200.0  Avg.Score: -200.00, eps-greedy: 0.010 Time: 00:00:50
# Episode:   230 Score: -200.0  Avg.Score: -200.00, eps-greedy: 0.010 Time: 00:00:52
# Episode:   240 Score: -200.0  Avg.Score: -199.14, eps-greedy: 0.010 Time: 00:00:54
# Episode:   250 Score: -200.0  Avg.Score: -199.14, eps-greedy: 0.010 Time: 00:00:57
# Episode:   260 Score: -200.0  Avg.Score: -199.14, eps-greedy: 0.010 Time: 00:00:59
# Episode:   270 Score: -200.0  Avg.Score: -199.14, eps-greedy: 0.010 Time: 00:01:01
# Episode:   280 Score: -200.0  Avg.Score: -199.14, eps-greedy: 0.010 Time: 00:01:03
# Episode:   290 Score: -200.0  Avg.Score: -199.14, eps-greedy: 0.010 Time: 00:01:06
# Episode:   300 Score: -200.0  Avg.Score: -199.14, eps-greedy: 0.010 Time: 00:01:08
# Episode:   310 Score: -200.0  Avg.Score: -199.14, eps-greedy: 0.010 Time: 00:01:10
# Episode:   320 Score: -200.0  Avg.Score: -199.14, eps-greedy: 0.010 Time: 00:01:13
# Episode:   330 Score: -200.0  Avg.Score: -199.14, eps-greedy: 0.010 Time: 00:01:15
# Episode:   340 Score: -200.0  Avg.Score: -200.00, eps-greedy: 0.010 Time: 00:01:17
# Episode:   350 Score: -200.0  Avg.Score: -200.00, eps-greedy: 0.010 Time: 00:01:20
# Episode:   360 Score: -200.0  Avg.Score: -200.00, eps-greedy: 0.010 Time: 00:01:22
# Episode:   370 Score: -200.0  Avg.Score: -200.00, eps-greedy: 0.010 Time: 00:01:24
# Episode:   380 Score: -200.0  Avg.Score: -200.00, eps-greedy: 0.010 Time: 00:01:26
# Episode:   390 Score: -200.0  Avg.Score: -200.00, eps-greedy: 0.010 Time: 00:01:29
# Episode:   400 Score: -200.0  Avg.Score: -200.00, eps-greedy: 0.010 Time: 00:01:31
# Episode:   410 Score: -200.0  Avg.Score: -200.00, eps-greedy: 0.010 Time: 00:01:33
# Episode:   420 Score: -200.0  Avg.Score: -200.00, eps-greedy: 0.010 Time: 00:01:36
# Episode:   430 Score: -200.0  Avg.Score: -200.00, eps-greedy: 0.010 Time: 00:01:38
# Episode:   440 Score: -200.0  Avg.Score: -200.00, eps-greedy: 0.010 Time: 00:01:40
# Episode:   450 Score: -200.0  Avg.Score: -200.00, eps-greedy: 0.010 Time: 00:01:42
# Episode:   460 Score: -200.0  Avg.Score: -200.00, eps-greedy: 0.010 Time: 00:01:45
# Episode:   470 Score: -200.0  Avg.Score: -200.00, eps-greedy: 0.010 Time: 00:01:47
# Episode:   480 Score: -200.0  Avg.Score: -199.95, eps-greedy: 0.010 Time: 00:01:49
# Episode:   490 Score: -200.0  Avg.Score: -199.28, eps-greedy: 0.010 Time: 00:01:52
# Episode:   500 Score: -178.0  Avg.Score: -198.09, eps-greedy: 0.010 Time: 00:01:54
# Episode:   510 Score: -200.0  Avg.Score: -196.20, eps-greedy: 0.010 Time: 00:01:56
# Episode:   520 Score: -200.0  Avg.Score: -196.00, eps-greedy: 0.010 Time: 00:01:58
# Episode:   530 Score: -200.0  Avg.Score: -193.40, eps-greedy: 0.010 Time: 00:02:00
# Episode:   540 Score: -185.0  Avg.Score: -193.25, eps-greedy: 0.010 Time: 00:02:02
# Episode:   550 Score: -155.0  Avg.Score: -192.24, eps-greedy: 0.010 Time: 00:02:05
# Episode:   560 Score: -200.0  Avg.Score: -190.13, eps-greedy: 0.010 Time: 00:02:07
# Episode:   570 Score: -200.0  Avg.Score: -188.96, eps-greedy: 0.010 Time: 00:02:09
# Episode:   580 Score: -200.0  Avg.Score: -187.49, eps-greedy: 0.010 Time: 00:02:11
# Episode:   590 Score: -186.0  Avg.Score: -187.29, eps-greedy: 0.010 Time: 00:02:13
# Episode:   600 Score: -186.0  Avg.Score: -187.53, eps-greedy: 0.010 Time: 00:02:15
# Episode:   610 Score: -200.0  Avg.Score: -187.94, eps-greedy: 0.010 Time: 00:02:17
# Episode:   620 Score: -200.0  Avg.Score: -187.04, eps-greedy: 0.010 Time: 00:02:20
# Episode:   630 Score: -124.0  Avg.Score: -188.11, eps-greedy: 0.010 Time: 00:02:22
# Episode:   640 Score: -200.0  Avg.Score: -188.26, eps-greedy: 0.010 Time: 00:02:24
# Episode:   650 Score: -200.0  Avg.Score: -189.13, eps-greedy: 0.010 Time: 00:02:26
# Episode:   660 Score: -200.0  Avg.Score: -190.24, eps-greedy: 0.010 Time: 00:02:28
# Episode:   670 Score: -200.0  Avg.Score: -191.41, eps-greedy: 0.010 Time: 00:02:31
# Episode:   680 Score: -200.0  Avg.Score: -192.70, eps-greedy: 0.010 Time: 00:02:33
# Episode:   690 Score: -200.0  Avg.Score: -193.57, eps-greedy: 0.010 Time: 00:02:35
# Episode:   700 Score: -200.0  Avg.Score: -193.81, eps-greedy: 0.010 Time: 00:02:38
# Episode:   710 Score: -200.0  Avg.Score: -194.19, eps-greedy: 0.010 Time: 00:02:40
# Episode:   720 Score: -200.0  Avg.Score: -194.75, eps-greedy: 0.010 Time: 00:02:42
# Episode:   730 Score: -198.0  Avg.Score: -196.26, eps-greedy: 0.010 Time: 00:02:44
# Episode:   740 Score: -200.0  Avg.Score: -195.50, eps-greedy: 0.010 Time: 00:02:46
# Episode:   750 Score: -200.0  Avg.Score: -195.36, eps-greedy: 0.010 Time: 00:02:49
# Episode:   760 Score: -142.0  Avg.Score: -195.31, eps-greedy: 0.010 Time: 00:02:51
# Episode:   770 Score: -200.0  Avg.Score: -195.22, eps-greedy: 0.010 Time: 00:02:53
# Episode:   780 Score: -200.0  Avg.Score: -194.28, eps-greedy: 0.010 Time: 00:02:55
# Episode:   790 Score: -184.0  Avg.Score: -193.38, eps-greedy: 0.010 Time: 00:02:58
# Episode:   800 Score: -172.0  Avg.Score: -191.95, eps-greedy: 0.010 Time: 00:03:00
# Episode:   810 Score: -182.0  Avg.Score: -192.07, eps-greedy: 0.010 Time: 00:03:02
# Episode:   820 Score: -200.0  Avg.Score: -192.14, eps-greedy: 0.010 Time: 00:03:04
# Episode:   830 Score: -200.0  Avg.Score: -191.69, eps-greedy: 0.010 Time: 00:03:06
# Episode:   840 Score: -200.0  Avg.Score: -191.81, eps-greedy: 0.010 Time: 00:03:09
# Episode:   850 Score: -200.0  Avg.Score: -191.94, eps-greedy: 0.010 Time: 00:03:11
# Episode:   860 Score: -200.0  Avg.Score: -192.99, eps-greedy: 0.010 Time: 00:03:13
# Episode:   870 Score: -200.0  Avg.Score: -192.42, eps-greedy: 0.010 Time: 00:03:15
# Episode:   880 Score: -200.0  Avg.Score: -193.59, eps-greedy: 0.010 Time: 00:03:18
# Episode:   890 Score: -200.0  Avg.Score: -194.26, eps-greedy: 0.010 Time: 00:03:20
# Episode:   900 Score: -200.0  Avg.Score: -196.15, eps-greedy: 0.010 Time: 00:03:22
# Episode:   910 Score: -200.0  Avg.Score: -196.87, eps-greedy: 0.010 Time: 00:03:25
# Episode:   920 Score: -177.0  Avg.Score: -194.26, eps-greedy: 0.010 Time: 00:03:27
# Episode:   930 Score: -200.0  Avg.Score: -193.04, eps-greedy: 0.010 Time: 00:03:29
# Episode:   940 Score: -144.0  Avg.Score: -189.89, eps-greedy: 0.010 Time: 00:03:31
# Episode:   950 Score: -153.0  Avg.Score: -185.19, eps-greedy: 0.010 Time: 00:03:32
# Episode:   960 Score: -150.0  Avg.Score: -180.58, eps-greedy: 0.010 Time: 00:03:34
# Episode:   970 Score: -141.0  Avg.Score: -176.83, eps-greedy: 0.010 Time: 00:03:36
# Episode:   980 Score: -144.0  Avg.Score: -171.06, eps-greedy: 0.010 Time: 00:03:37
# Episode:   990 Score: -138.0  Avg.Score: -168.28, eps-greedy: 0.010 Time: 00:03:39
# Episode:  1000 Score: -161.0  Avg.Score: -164.02, eps-greedy: 0.010 Time: 00:03:41
# Episode:  1010 Score: -145.0  Avg.Score: -160.92, eps-greedy: 0.010 Time: 00:03:43
# Episode:  1020 Score: -142.0  Avg.Score: -160.64, eps-greedy: 0.010 Time: 00:03:45
# Episode:  1030 Score: -168.0  Avg.Score: -157.48, eps-greedy: 0.010 Time: 00:03:47
# Episode:  1040 Score: -131.0  Avg.Score: -156.97, eps-greedy: 0.010 Time: 00:03:49
# Episode:  1050 Score: -151.0  Avg.Score: -155.89, eps-greedy: 0.010 Time: 00:03:50
# Episode:  1060 Score: -135.0  Avg.Score: -155.11, eps-greedy: 0.010 Time: 00:03:52
# Episode:  1070 Score: -134.0  Avg.Score: -154.42, eps-greedy: 0.010 Time: 00:03:54
# Episode:  1080 Score: -154.0  Avg.Score: -154.56, eps-greedy: 0.010 Time: 00:03:55
# Episode:  1090 Score: -154.0  Avg.Score: -152.31, eps-greedy: 0.010 Time: 00:03:57
# Episode:  1100 Score: -161.0  Avg.Score: -150.55, eps-greedy: 0.010 Time: 00:03:59
# Episode:  1110 Score: -163.0  Avg.Score: -147.70, eps-greedy: 0.010 Time: 00:04:00
# Episode:  1120 Score: -193.0  Avg.Score: -147.16, eps-greedy: 0.010 Time: 00:04:02
# Episode:  1130 Score: -131.0  Avg.Score: -143.46, eps-greedy: 0.010 Time: 00:04:03
# Episode:  1140 Score: -111.0  Avg.Score: -139.95, eps-greedy: 0.010 Time: 00:04:05
# Episode:  1150 Score: -134.0  Avg.Score: -138.23, eps-greedy: 0.010 Time: 00:04:06
# Episode:  1160 Score: -106.0  Avg.Score: -136.41, eps-greedy: 0.010 Time: 00:04:08
# Episode:  1170 Score: -99.0  Avg.Score: -132.33, eps-greedy: 0.010 Time: 00:04:09
# Episode:  1180 Score: -101.0  Avg.Score: -129.74, eps-greedy: 0.010 Time: 00:04:10
# Episode:  1190 Score: -172.0  Avg.Score: -127.76, eps-greedy: 0.010 Time: 00:04:12
# Episode:  1200 Score: -91.0  Avg.Score: -126.19, eps-greedy: 0.010 Time: 00:04:13
# Episode:  1210 Score: -131.0  Avg.Score: -124.93, eps-greedy: 0.010 Time: 00:04:15
# Episode:  1220 Score: -94.0  Avg.Score: -122.01, eps-greedy: 0.010 Time: 00:04:16
# Episode:  1230 Score: -92.0  Avg.Score: -121.55, eps-greedy: 0.010 Time: 00:04:17
# Episode:  1240 Score: -147.0  Avg.Score: -122.60, eps-greedy: 0.010 Time: 00:04:19
# Episode:  1250 Score: -93.0  Avg.Score: -119.72, eps-greedy: 0.010 Time: 00:04:20
# Episode:  1260 Score: -129.0  Avg.Score: -119.91, eps-greedy: 0.010 Time: 00:04:21
# Episode:  1270 Score: -185.0  Avg.Score: -122.19, eps-greedy: 0.010 Time: 00:04:23
# Episode:  1280 Score: -151.0  Avg.Score: -123.26, eps-greedy: 0.010 Time: 00:04:24
# Episode:  1290 Score: -93.0  Avg.Score: -123.35, eps-greedy: 0.010 Time: 00:04:26
# Episode:  1300 Score: -133.0  Avg.Score: -124.32, eps-greedy: 0.010 Time: 00:04:27
# Episode:  1310 Score: -138.0  Avg.Score: -126.78, eps-greedy: 0.010 Time: 00:04:29
# Episode:  1320 Score: -99.0  Avg.Score: -126.36, eps-greedy: 0.010 Time: 00:04:31
# Episode:  1330 Score: -88.0  Avg.Score: -129.73, eps-greedy: 0.010 Time: 00:04:32
# Episode:  1340 Score: -96.0  Avg.Score: -129.98, eps-greedy: 0.010 Time: 00:04:34
# Episode:  1350 Score: -181.0  Avg.Score: -133.21, eps-greedy: 0.010 Time: 00:04:35
# Episode:  1360 Score: -170.0  Avg.Score: -132.06, eps-greedy: 0.010 Time: 00:04:37
# Episode:  1370 Score: -145.0  Avg.Score: -132.58, eps-greedy: 0.010 Time: 00:04:38
# Episode:  1380 Score: -88.0  Avg.Score: -131.65, eps-greedy: 0.010 Time: 00:04:40
# Episode:  1390 Score: -92.0  Avg.Score: -130.82, eps-greedy: 0.010 Time: 00:04:41
# Episode:  1400 Score: -86.0  Avg.Score: -132.00, eps-greedy: 0.010 Time: 00:04:43
# Episode:  1410 Score: -103.0  Avg.Score: -128.84, eps-greedy: 0.010 Time: 00:04:44
# Episode:  1420 Score: -148.0  Avg.Score: -127.04, eps-greedy: 0.010 Time: 00:04:45
# Episode:  1430 Score: -86.0  Avg.Score: -124.09, eps-greedy: 0.010 Time: 00:04:47
# Episode:  1440 Score: -139.0  Avg.Score: -123.95, eps-greedy: 0.010 Time: 00:04:48
# Episode:  1450 Score: -94.0  Avg.Score: -122.73, eps-greedy: 0.010 Time: 00:04:50
# Episode:  1460 Score: -87.0  Avg.Score: -123.53, eps-greedy: 0.010 Time: 00:04:51
# Episode:  1470 Score: -156.0  Avg.Score: -123.39, eps-greedy: 0.010 Time: 00:04:53
# Episode:  1480 Score: -89.0  Avg.Score: -122.88, eps-greedy: 0.010 Time: 00:04:54
# Episode:  1490 Score: -94.0  Avg.Score: -125.50, eps-greedy: 0.010 Time: 00:04:56
# Episode:  1500 Score: -182.0  Avg.Score: -126.73, eps-greedy: 0.010 Time: 00:04:57
# Episode:  1510 Score: -88.0  Avg.Score: -127.89, eps-greedy: 0.010 Time: 00:04:59
# Episode:  1520 Score: -173.0  Avg.Score: -128.97, eps-greedy: 0.010 Time: 00:05:00
# Episode:  1530 Score: -89.0  Avg.Score: -131.66, eps-greedy: 0.010 Time: 00:05:02
# Episode:  1540 Score: -131.0  Avg.Score: -130.63, eps-greedy: 0.010 Time: 00:05:03
# Episode:  1550 Score: -108.0  Avg.Score: -129.47, eps-greedy: 0.010 Time: 00:05:05
# Episode:  1560 Score: -124.0  Avg.Score: -127.95, eps-greedy: 0.010 Time: 00:05:06
# Episode:  1570 Score: -109.0  Avg.Score: -125.29, eps-greedy: 0.010 Time: 00:05:07
# Episode:  1580 Score: -118.0  Avg.Score: -124.58, eps-greedy: 0.010 Time: 00:05:08
# Episode:  1590 Score: -117.0  Avg.Score: -121.82, eps-greedy: 0.010 Time: 00:05:10
# Episode:  1600 Score: -140.0  Avg.Score: -118.31, eps-greedy: 0.010 Time: 00:05:11
# Episode:  1610 Score: -121.0  Avg.Score: -117.97, eps-greedy: 0.010 Time: 00:05:13
# Episode:  1620 Score: -136.0  Avg.Score: -119.29, eps-greedy: 0.010 Time: 00:05:14
# Episode:  1630 Score: -133.0  Avg.Score: -118.26, eps-greedy: 0.010 Time: 00:05:16
# Episode:  1640 Score: -139.0  Avg.Score: -121.96, eps-greedy: 0.010 Time: 00:05:17
# Episode:  1650 Score: -200.0  Avg.Score: -127.45, eps-greedy: 0.010 Time: 00:05:19
# Episode:  1660 Score: -133.0  Avg.Score: -130.27, eps-greedy: 0.010 Time: 00:05:21
# Episode:  1670 Score: -129.0  Avg.Score: -134.85, eps-greedy: 0.010 Time: 00:05:23
# Episode:  1680 Score: -200.0  Avg.Score: -139.14, eps-greedy: 0.010 Time: 00:05:24
# Episode:  1690 Score: -200.0  Avg.Score: -145.74, eps-greedy: 0.010 Time: 00:05:27
# Episode:  1700 Score: -135.0  Avg.Score: -150.55, eps-greedy: 0.010 Time: 00:05:28
# Episode:  1710 Score: -154.0  Avg.Score: -153.78, eps-greedy: 0.010 Time: 00:05:30
# Episode:  1720 Score: -129.0  Avg.Score: -156.25, eps-greedy: 0.010 Time: 00:05:32
# Episode:  1730 Score: -131.0  Avg.Score: -157.43, eps-greedy: 0.010 Time: 00:05:34
# Episode:  1740 Score: -118.0  Avg.Score: -157.98, eps-greedy: 0.010 Time: 00:05:36
# Episode:  1750 Score: -122.0  Avg.Score: -154.49, eps-greedy: 0.010 Time: 00:05:37
# Episode:  1760 Score: -200.0  Avg.Score: -153.45, eps-greedy: 0.010 Time: 00:05:39
# Episode:  1770 Score: -110.0  Avg.Score: -152.18, eps-greedy: 0.010 Time: 00:05:40
# Episode:  1780 Score: -123.0  Avg.Score: -148.24, eps-greedy: 0.010 Time: 00:05:42
# Episode:  1790 Score: -106.0  Avg.Score: -140.90, eps-greedy: 0.010 Time: 00:05:43
# Episode:  1800 Score: -119.0  Avg.Score: -137.13, eps-greedy: 0.010 Time: 00:05:44
# Episode:  1810 Score: -112.0  Avg.Score: -134.53, eps-greedy: 0.010 Time: 00:05:46
# Episode:  1820 Score: -127.0  Avg.Score: -130.45, eps-greedy: 0.010 Time: 00:05:47
# Episode:  1830 Score: -85.0  Avg.Score: -128.54, eps-greedy: 0.010 Time: 00:05:49
# Episode:  1840 Score: -108.0  Avg.Score: -125.25, eps-greedy: 0.010 Time: 00:05:50
# Episode:  1850 Score: -107.0  Avg.Score: -125.54, eps-greedy: 0.010 Time: 00:05:52
# Episode:  1860 Score: -105.0  Avg.Score: -125.32, eps-greedy: 0.010 Time: 00:05:53
# Episode:  1870 Score: -145.0  Avg.Score: -125.57, eps-greedy: 0.010 Time: 00:05:55
# Episode:  1880 Score: -121.0  Avg.Score: -128.02, eps-greedy: 0.010 Time: 00:05:56
# Episode:  1890 Score: -99.0  Avg.Score: -130.75, eps-greedy: 0.010 Time: 00:05:58
# Episode:  1900 Score: -184.0  Avg.Score: -132.64, eps-greedy: 0.010 Time: 00:06:00
# Episode:  1910 Score: -182.0  Avg.Score: -135.38, eps-greedy: 0.010 Time: 00:06:02
# Episode:  1920 Score: -85.0  Avg.Score: -138.28, eps-greedy: 0.010 Time: 00:06:03
# Episode:  1930 Score: -124.0  Avg.Score: -139.98, eps-greedy: 0.010 Time: 00:06:05
# Episode:  1940 Score: -166.0  Avg.Score: -141.03, eps-greedy: 0.010 Time: 00:06:07
# Episode:  1950 Score: -200.0  Avg.Score: -142.72, eps-greedy: 0.010 Time: 00:06:08
# Episode:  1960 Score: -125.0  Avg.Score: -144.89, eps-greedy: 0.010 Time: 00:06:10
# Episode:  1970 Score: -124.0  Avg.Score: -146.66, eps-greedy: 0.010 Time: 00:06:12
# Episode:  1980 Score: -200.0  Avg.Score: -149.36, eps-greedy: 0.010 Time: 00:06:14
# Episode:  1990 Score: -200.0  Avg.Score: -154.40, eps-greedy: 0.010 Time: 00:06:16
# Episode:  2000 Score: -197.0  Avg.Score: -157.74, eps-greedy: 0.010 Time: 00:06:18
# Episode:  2010 Score: -108.0  Avg.Score: -157.50, eps-greedy: 0.010 Time: 00:06:20
# Episode:  2020 Score: -175.0  Avg.Score: -158.75, eps-greedy: 0.010 Time: 00:06:22
# Episode:  2030 Score: -181.0  Avg.Score: -159.59, eps-greedy: 0.010 Time: 00:06:23
# Episode:  2040 Score: -154.0  Avg.Score: -159.07, eps-greedy: 0.010 Time: 00:06:25
# Episode:  2050 Score: -88.0  Avg.Score: -157.07, eps-greedy: 0.010 Time: 00:06:26
# Episode:  2060 Score: -140.0  Avg.Score: -156.46, eps-greedy: 0.010 Time: 00:06:28
# Episode:  2070 Score: -166.0  Avg.Score: -154.37, eps-greedy: 0.010 Time: 00:06:30
# Episode:  2080 Score: -105.0  Avg.Score: -151.26, eps-greedy: 0.010 Time: 00:06:31
# Episode:  2090 Score: -107.0  Avg.Score: -147.07, eps-greedy: 0.010 Time: 00:06:33
# Episode:  2100 Score: -116.0  Avg.Score: -141.23, eps-greedy: 0.010 Time: 00:06:34
# Episode:  2110 Score: -92.0  Avg.Score: -138.82, eps-greedy: 0.010 Time: 00:06:36
# Episode:  2120 Score: -107.0  Avg.Score: -135.26, eps-greedy: 0.010 Time: 00:06:37
# Episode:  2130 Score: -111.0  Avg.Score: -132.84, eps-greedy: 0.010 Time: 00:06:39
# Episode:  2140 Score: -90.0  Avg.Score: -130.34, eps-greedy: 0.010 Time: 00:06:40
# Episode:  2150 Score: -111.0  Avg.Score: -130.84, eps-greedy: 0.010 Time: 00:06:42
# Episode:  2160 Score: -106.0  Avg.Score: -130.49, eps-greedy: 0.010 Time: 00:06:43
# Episode:  2170 Score: -111.0  Avg.Score: -131.08, eps-greedy: 0.010 Time: 00:06:45
# Episode:  2180 Score: -97.0  Avg.Score: -131.26, eps-greedy: 0.010 Time: 00:06:46
# Episode:  2190 Score: -148.0  Avg.Score: -128.83, eps-greedy: 0.010 Time: 00:06:48
# Episode:  2200 Score: -114.0  Avg.Score: -128.70, eps-greedy: 0.010 Time: 00:06:49
# Episode:  2210 Score: -174.0  Avg.Score: -128.38, eps-greedy: 0.010 Time: 00:06:51
# Episode:  2220 Score: -93.0  Avg.Score: -128.00, eps-greedy: 0.010 Time: 00:06:52
# Episode:  2230 Score: -125.0  Avg.Score: -126.30, eps-greedy: 0.010 Time: 00:06:53
# Episode:  2240 Score: -87.0  Avg.Score: -126.98, eps-greedy: 0.010 Time: 00:06:55
# Episode:  2250 Score: -114.0  Avg.Score: -126.18, eps-greedy: 0.010 Time: 00:06:56
# Episode:  2260 Score: -118.0  Avg.Score: -123.38, eps-greedy: 0.010 Time: 00:06:57
# Episode:  2270 Score: -148.0  Avg.Score: -121.66, eps-greedy: 0.010 Time: 00:06:59
# Episode:  2280 Score: -110.0  Avg.Score: -120.50, eps-greedy: 0.010 Time: 00:07:00
# Episode:  2290 Score: -124.0  Avg.Score: -122.29, eps-greedy: 0.010 Time: 00:07:02
# Episode:  2300 Score: -112.0  Avg.Score: -121.43, eps-greedy: 0.010 Time: 00:07:03
# Episode:  2310 Score: -95.0  Avg.Score: -119.21, eps-greedy: 0.010 Time: 00:07:05
# Episode:  2320 Score: -117.0  Avg.Score: -119.29, eps-greedy: 0.010 Time: 00:07:06
# Episode:  2330 Score: -129.0  Avg.Score: -121.36, eps-greedy: 0.010 Time: 00:07:07
# Episode:  2340 Score: -118.0  Avg.Score: -121.68, eps-greedy: 0.010 Time: 00:07:09
# Episode:  2350 Score: -110.0  Avg.Score: -124.07, eps-greedy: 0.010 Time: 00:07:10
# Episode:  2360 Score: -105.0  Avg.Score: -124.96, eps-greedy: 0.010 Time: 00:07:12
# Episode:  2370 Score: -111.0  Avg.Score: -123.75, eps-greedy: 0.010 Time: 00:07:13
# Episode:  2380 Score: -109.0  Avg.Score: -123.17, eps-greedy: 0.010 Time: 00:07:15
# Episode:  2390 Score: -88.0  Avg.Score: -119.69, eps-greedy: 0.010 Time: 00:07:16
# Episode:  2400 Score: -107.0  Avg.Score: -118.80, eps-greedy: 0.010 Time: 00:07:17
# Episode:  2410 Score: -133.0  Avg.Score: -119.60, eps-greedy: 0.010 Time: 00:07:18
# Episode:  2420 Score: -111.0  Avg.Score: -119.40, eps-greedy: 0.010 Time: 00:07:20
# Episode:  2430 Score: -103.0  Avg.Score: -117.80, eps-greedy: 0.010 Time: 00:07:21
# Episode:  2440 Score: -112.0  Avg.Score: -117.54, eps-greedy: 0.010 Time: 00:07:22
# Episode:  2450 Score: -117.0  Avg.Score: -114.51, eps-greedy: 0.010 Time: 00:07:24
# Episode:  2460 Score: -115.0  Avg.Score: -113.86, eps-greedy: 0.010 Time: 00:07:25
# Episode:  2470 Score: -154.0  Avg.Score: -115.42, eps-greedy: 0.010 Time: 00:07:27
# Episode:  2480 Score: -120.0  Avg.Score: -117.24, eps-greedy: 0.010 Time: 00:07:28
# Episode:  2490 Score: -108.0  Avg.Score: -118.65, eps-greedy: 0.010 Time: 00:07:29
# Episode:  2500 Score: -120.0  Avg.Score: -123.65, eps-greedy: 0.010 Time: 00:07:31
# Episode:  2510 Score: -99.0  Avg.Score: -124.81, eps-greedy: 0.010 Time: 00:07:33
# Episode:  2520 Score: -113.0  Avg.Score: -126.18, eps-greedy: 0.010 Time: 00:07:34
# Episode:  2530 Score: -107.0  Avg.Score: -126.77, eps-greedy: 0.010 Time: 00:07:36
# Episode:  2540 Score: -116.0  Avg.Score: -127.35, eps-greedy: 0.010 Time: 00:07:37
# Episode:  2550 Score: -137.0  Avg.Score: -128.59, eps-greedy: 0.010 Time: 00:07:39
# Episode:  2560 Score: -90.0  Avg.Score: -130.09, eps-greedy: 0.010 Time: 00:07:40
# Episode:  2570 Score: -125.0  Avg.Score: -130.38, eps-greedy: 0.010 Time: 00:07:42
# Episode:  2580 Score: -116.0  Avg.Score: -132.32, eps-greedy: 0.010 Time: 00:07:43
# Episode:  2590 Score: -150.0  Avg.Score: -136.65, eps-greedy: 0.010 Time: 00:07:45
# Episode:  2600 Score: -139.0  Avg.Score: -134.84, eps-greedy: 0.010 Time: 00:07:47
# Episode:  2610 Score: -130.0  Avg.Score: -136.41, eps-greedy: 0.010 Time: 00:07:48
# Episode:  2620 Score: -131.0  Avg.Score: -137.67, eps-greedy: 0.010 Time: 00:07:50
# Episode:  2630 Score: -141.0  Avg.Score: -139.63, eps-greedy: 0.010 Time: 00:07:52
# Episode:  2640 Score: -131.0  Avg.Score: -140.45, eps-greedy: 0.010 Time: 00:07:53
# Episode:  2650 Score: -128.0  Avg.Score: -141.47, eps-greedy: 0.010 Time: 00:07:55
# Episode:  2660 Score: -130.0  Avg.Score: -140.94, eps-greedy: 0.010 Time: 00:07:56
# Episode:  2670 Score: -100.0  Avg.Score: -140.57, eps-greedy: 0.010 Time: 00:07:58
# Episode:  2680 Score: -113.0  Avg.Score: -137.20, eps-greedy: 0.010 Time: 00:07:59
# Episode:  2690 Score: -113.0  Avg.Score: -133.41, eps-greedy: 0.010 Time: 00:08:01
# Episode:  2700 Score: -116.0  Avg.Score: -131.43, eps-greedy: 0.010 Time: 00:08:02
# Episode:  2710 Score: -87.0  Avg.Score: -128.25, eps-greedy: 0.010 Time: 00:08:03
# Episode:  2720 Score: -116.0  Avg.Score: -126.39, eps-greedy: 0.010 Time: 00:08:05
# Episode:  2730 Score: -110.0  Avg.Score: -123.76, eps-greedy: 0.010 Time: 00:08:06
# Episode:  2740 Score: -171.0  Avg.Score: -123.21, eps-greedy: 0.010 Time: 00:08:08
# Episode:  2750 Score: -109.0  Avg.Score: -121.64, eps-greedy: 0.010 Time: 00:08:09
# Episode:  2760 Score: -117.0  Avg.Score: -120.32, eps-greedy: 0.010 Time: 00:08:10
# Episode:  2770 Score: -106.0  Avg.Score: -119.23, eps-greedy: 0.010 Time: 00:08:12
# Episode:  2780 Score: -116.0  Avg.Score: -118.29, eps-greedy: 0.010 Time: 00:08:13
# Episode:  2790 Score: -111.0  Avg.Score: -117.01, eps-greedy: 0.010 Time: 00:08:14
# Episode:  2800 Score: -108.0  Avg.Score: -117.21, eps-greedy: 0.010 Time: 00:08:16
# Episode:  2810 Score: -107.0  Avg.Score: -118.25, eps-greedy: 0.010 Time: 00:08:17
# Episode:  2820 Score: -109.0  Avg.Score: -117.66, eps-greedy: 0.010 Time: 00:08:18
# Episode:  2830 Score: -110.0  Avg.Score: -117.74, eps-greedy: 0.010 Time: 00:08:20
# Episode:  2840 Score: -96.0  Avg.Score: -115.65, eps-greedy: 0.010 Time: 00:08:21
# Episode:  2850 Score: -121.0  Avg.Score: -114.14, eps-greedy: 0.010 Time: 00:08:22
# Episode:  2860 Score: -97.0  Avg.Score: -113.67, eps-greedy: 0.010 Time: 00:08:23
# Episode:  2870 Score: -93.0  Avg.Score: -111.98, eps-greedy: 0.010 Time: 00:08:25
# Episode:  2880 Score: -85.0  Avg.Score: -112.03, eps-greedy: 0.010 Time: 00:08:26
# Episode:  2890 Score: -106.0  Avg.Score: -114.46, eps-greedy: 0.010 Time: 00:08:27
# Episode:  2900 Score: -147.0  Avg.Score: -117.18, eps-greedy: 0.010 Time: 00:08:29
# Episode:  2910 Score: -86.0  Avg.Score: -117.61, eps-greedy: 0.010 Time: 00:08:31
# Episode:  2920 Score: -187.0  Avg.Score: -118.85, eps-greedy: 0.010 Time: 00:08:32
# Episode:  2930 Score: -152.0  Avg.Score: -119.90, eps-greedy: 0.010 Time: 00:08:33
# Episode:  2940 Score: -116.0  Avg.Score: -119.61, eps-greedy: 0.010 Time: 00:08:35
# Episode:  2950 Score: -93.0  Avg.Score: -122.77, eps-greedy: 0.010 Time: 00:08:36
# Episode:  2960 Score: -113.0  Avg.Score: -124.53, eps-greedy: 0.010 Time: 00:08:38
# Episode:  2970 Score: -116.0  Avg.Score: -125.74, eps-greedy: 0.010 Time: 00:08:39
# Episode:  2980 Score: -150.0  Avg.Score: -127.51, eps-greedy: 0.010 Time: 00:08:40
# Episode:  2990 Score: -154.0  Avg.Score: -126.36, eps-greedy: 0.010 Time: 00:08:42
# Episode:  3000 Score: -114.0  Avg.Score: -123.66, eps-greedy: 0.010 Time: 00:08:43
# Episode:  3010 Score: -127.0  Avg.Score: -123.51, eps-greedy: 0.010 Time: 00:08:45
# Episode:  3020 Score: -130.0  Avg.Score: -122.37, eps-greedy: 0.010 Time: 00:08:46
# Episode:  3030 Score: -86.0  Avg.Score: -121.84, eps-greedy: 0.010 Time: 00:08:47
# Episode:  3040 Score: -122.0  Avg.Score: -124.56, eps-greedy: 0.010 Time: 00:08:49
# Episode:  3050 Score: -160.0  Avg.Score: -125.35, eps-greedy: 0.010 Time: 00:08:51
# Episode:  3060 Score: -103.0  Avg.Score: -126.89, eps-greedy: 0.010 Time: 00:08:52
# Episode:  3070 Score: -110.0  Avg.Score: -128.38, eps-greedy: 0.010 Time: 00:08:54
# Episode:  3080 Score: -123.0  Avg.Score: -127.61, eps-greedy: 0.010 Time: 00:08:55
# Episode:  3090 Score: -123.0  Avg.Score: -127.29, eps-greedy: 0.010 Time: 00:08:57
# Episode:  3100 Score: -117.0  Avg.Score: -128.10, eps-greedy: 0.010 Time: 00:08:58
# Episode:  3110 Score: -120.0  Avg.Score: -127.78, eps-greedy: 0.010 Time: 00:08:59
# Episode:  3120 Score: -94.0  Avg.Score: -127.22, eps-greedy: 0.010 Time: 00:09:01
# Episode:  3130 Score: -118.0  Avg.Score: -127.25, eps-greedy: 0.010 Time: 00:09:02
# Episode:  3140 Score: -117.0  Avg.Score: -125.29, eps-greedy: 0.010 Time: 00:09:03
# Episode:  3150 Score: -114.0  Avg.Score: -121.70, eps-greedy: 0.010 Time: 00:09:05
# Episode:  3160 Score: -125.0  Avg.Score: -119.10, eps-greedy: 0.010 Time: 00:09:06
# Episode:  3170 Score: -99.0  Avg.Score: -116.58, eps-greedy: 0.010 Time: 00:09:07
# Episode:  3180 Score: -170.0  Avg.Score: -116.12, eps-greedy: 0.010 Time: 00:09:09
# Episode:  3190 Score: -182.0  Avg.Score: -115.99, eps-greedy: 0.010 Time: 00:09:10
# Episode:  3200 Score: -168.0  Avg.Score: -117.20, eps-greedy: 0.010 Time: 00:09:12
# Episode:  3210 Score: -134.0  Avg.Score: -117.92, eps-greedy: 0.010 Time: 00:09:13
# Episode:  3220 Score: -149.0  Avg.Score: -118.22, eps-greedy: 0.010 Time: 00:09:14
# Episode:  3230 Score: -107.0  Avg.Score: -119.15, eps-greedy: 0.010 Time: 00:09:16
# Episode:  3240 Score: -152.0  Avg.Score: -120.20, eps-greedy: 0.010 Time: 00:09:17
# Episode:  3250 Score: -86.0  Avg.Score: -122.90, eps-greedy: 0.010 Time: 00:09:19
# Episode:  3260 Score: -87.0  Avg.Score: -124.87, eps-greedy: 0.010 Time: 00:09:20
# Episode:  3270 Score: -106.0  Avg.Score: -127.48, eps-greedy: 0.010 Time: 00:09:22
# Episode:  3280 Score: -110.0  Avg.Score: -128.79, eps-greedy: 0.010 Time: 00:09:23
# Episode:  3290 Score: -156.0  Avg.Score: -130.42, eps-greedy: 0.010 Time: 00:09:25
# Episode:  3300 Score: -153.0  Avg.Score: -128.62, eps-greedy: 0.010 Time: 00:09:26
# Episode:  3310 Score: -142.0  Avg.Score: -128.04, eps-greedy: 0.010 Time: 00:09:28
# Episode:  3320 Score: -93.0  Avg.Score: -129.97, eps-greedy: 0.010 Time: 00:09:29
# Episode:  3330 Score: -177.0  Avg.Score: -129.78, eps-greedy: 0.010 Time: 00:09:31
# Episode:  3340 Score: -156.0  Avg.Score: -129.37, eps-greedy: 0.010 Time: 00:09:32
# Episode:  3350 Score: -113.0  Avg.Score: -128.88, eps-greedy: 0.010 Time: 00:09:34
# Episode:  3360 Score: -146.0  Avg.Score: -129.59, eps-greedy: 0.010 Time: 00:09:35
# Episode:  3370 Score: -153.0  Avg.Score: -129.29, eps-greedy: 0.010 Time: 00:09:37
# Episode:  3380 Score: -142.0  Avg.Score: -129.31, eps-greedy: 0.010 Time: 00:09:38
# Episode:  3390 Score: -115.0  Avg.Score: -128.52, eps-greedy: 0.010 Time: 00:09:40
# Episode:  3400 Score: -104.0  Avg.Score: -126.74, eps-greedy: 0.010 Time: 00:09:41
# Episode:  3410 Score: -84.0  Avg.Score: -125.83, eps-greedy: 0.010 Time: 00:09:42
# Episode:  3420 Score: -93.0  Avg.Score: -122.45, eps-greedy: 0.010 Time: 00:09:43
# Episode:  3430 Score: -121.0  Avg.Score: -121.59, eps-greedy: 0.010 Time: 00:09:45
# Episode:  3440 Score: -111.0  Avg.Score: -121.34, eps-greedy: 0.010 Time: 00:09:46
# Episode:  3450 Score: -86.0  Avg.Score: -118.45, eps-greedy: 0.010 Time: 00:09:47
# Episode:  3460 Score: -166.0  Avg.Score: -115.69, eps-greedy: 0.010 Time: 00:09:49
# Episode:  3470 Score: -105.0  Avg.Score: -114.15, eps-greedy: 0.010 Time: 00:09:50
# Episode:  3480 Score: -155.0  Avg.Score: -115.35, eps-greedy: 0.010 Time: 00:09:52
# Episode:  3490 Score: -104.0  Avg.Score: -113.50, eps-greedy: 0.010 Time: 00:09:53
# Episode:  3500 Score: -114.0  Avg.Score: -115.58, eps-greedy: 0.010 Time: 00:09:54
# Episode:  3510 Score: -143.0  Avg.Score: -115.06, eps-greedy: 0.010 Time: 00:09:56
# Episode:  3520 Score: -112.0  Avg.Score: -117.62, eps-greedy: 0.010 Time: 00:09:57
# Episode:  3530 Score: -83.0  Avg.Score: -116.42, eps-greedy: 0.010 Time: 00:09:58
# Episode:  3540 Score: -106.0  Avg.Score: -116.10, eps-greedy: 0.010 Time: 00:10:00
# Episode:  3550 Score: -84.0  Avg.Score: -116.46, eps-greedy: 0.010 Time: 00:10:01
# Episode:  3560 Score: -84.0  Avg.Score: -117.25, eps-greedy: 0.010 Time: 00:10:02
# Episode:  3570 Score: -150.0  Avg.Score: -117.84, eps-greedy: 0.010 Time: 00:10:04
# Episode:  3580 Score: -169.0  Avg.Score: -116.20, eps-greedy: 0.010 Time: 00:10:05
# Episode:  3590 Score: -115.0  Avg.Score: -115.80, eps-greedy: 0.010 Time: 00:10:06
# Episode:  3600 Score: -109.0  Avg.Score: -115.87, eps-greedy: 0.010 Time: 00:10:08
# Episode:  3610 Score: -113.0  Avg.Score: -116.53, eps-greedy: 0.010 Time: 00:10:09
# Episode:  3620 Score: -106.0  Avg.Score: -114.49, eps-greedy: 0.010 Time: 00:10:10
# Episode:  3630 Score: -114.0  Avg.Score: -116.02, eps-greedy: 0.010 Time: 00:10:12
# Episode:  3640 Score: -111.0  Avg.Score: -116.37, eps-greedy: 0.010 Time: 00:10:13
# Episode:  3650 Score: -103.0  Avg.Score: -117.92, eps-greedy: 0.010 Time: 00:10:14
# Episode:  3660 Score: -163.0  Avg.Score: -118.81, eps-greedy: 0.010 Time: 00:10:16
# Episode:  3670 Score: -105.0  Avg.Score: -119.21, eps-greedy: 0.010 Time: 00:10:17
# Episode:  3680 Score: -110.0  Avg.Score: -119.45, eps-greedy: 0.010 Time: 00:10:19
# Episode:  3690 Score: -108.0  Avg.Score: -120.51, eps-greedy: 0.010 Time: 00:10:20
# Episode:  3700 Score: -105.0  Avg.Score: -118.79, eps-greedy: 0.010 Time: 00:10:21
# Episode:  3710 Score: -102.0  Avg.Score: -118.12, eps-greedy: 0.010 Time: 00:10:23
# Episode:  3720 Score: -110.0  Avg.Score: -117.68, eps-greedy: 0.010 Time: 00:10:24
# Episode:  3730 Score: -174.0  Avg.Score: -117.30, eps-greedy: 0.010 Time: 00:10:25
# Episode:  3740 Score: -108.0  Avg.Score: -116.49, eps-greedy: 0.010 Time: 00:10:26
# Episode:  3750 Score: -86.0  Avg.Score: -115.05, eps-greedy: 0.010 Time: 00:10:28
# Episode:  3760 Score: -113.0  Avg.Score: -112.89, eps-greedy: 0.010 Time: 00:10:29
# Episode:  3770 Score: -108.0  Avg.Score: -111.80, eps-greedy: 0.010 Time: 00:10:30
# Episode:  3780 Score: -113.0  Avg.Score: -110.46, eps-greedy: 0.010 Time: 00:10:31
#
#  MountainCart solved in 3782 episodes!	Average Score: -109.90

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

print('scores length: ', len(scores), ', avg_scores length: ', len(avg_scores))

fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(1, len(scores)+1), scores, label="Score")
plt.plot(np.arange(1, len(avg_scores)+1), avg_scores, label="Avg on 100 episodes")
plt.legend(bbox_to_anchor=(1.05, 1)) 
plt.ylabel('Score')
plt.xlabel('Episodes #')
plt.title('DQN Convergence (Avg Score: -109.99 | Episodes: 1539) with 16 hidden dimensions\n')
plt.show()
# Out:
# scores length:  3783 , avg_scores length:  3783
